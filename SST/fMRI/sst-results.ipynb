# %%
from nilearn import plotting
from nilearn import image
# %matplotlib inline
# Out:
# /Shared/pinc/sharedopt/apps/anaconda3/Linux/x86_64/5.1.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # ICA + 12MP

# %% [markdown]
# ## masked

# %%
withICA_masked='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/withICA/CorStop-CorGo_allsub.gfeat/cope1.feat/thresh_zstat1.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(withICA_masked, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICA12MPz.png')
plotting.plot_stat_map(withICA_masked, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICA12MPx.png')
plotting.plot_stat_map(withICA_masked, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICA12MPy.png')

# %% [markdown]
# ## no masked

# %%
withICA_nomask='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/withICA/CorStop-CorGo_allsub_nomask.gfeat/cope1.feat/thresh_zstat1.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(withICA_nomask, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICA12MPznomask.png')
plotting.plot_stat_map(withICA_nomask, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICA12MPxnomask.png')
plotting.plot_stat_map(withICA_nomask, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICA12MPynomask.png')

# %% [markdown]
# # 12MP

# %% [markdown]
# ## masked

# %%
noICA_masked='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_allsub.gfeat/cope1.feat/thresh_zstat1.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(noICA_masked, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/12MPz.png')
plotting.plot_stat_map(noICA_masked, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/12MPx.png')
plotting.plot_stat_map(noICA_masked, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/12MPy.png')

# %% [markdown]
# ## no masked

# %%
noICA_nomask='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_allsub_nomask.gfeat/cope1.feat/thresh_zstat1.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(noICA_masked, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/12MPznomask.png')
plotting.plot_stat_map(noICA_masked, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/12MPxnomask.png')
plotting.plot_stat_map(noICA_masked, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/12MPynomask.png')

# %% [markdown]
# # ICA no 12 MP
#
# ## Masked

# %%
ICAno12MP_masked='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/ICAno12MP/CorStop-CorGo_allsub.gfeat/cope1.feat/thresh_zstat1.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(ICAno12MP_masked, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICAno12MPz.png')
plotting.plot_stat_map(ICAno12MP_masked, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICAno12MPx.png')
plotting.plot_stat_map(ICAno12MP_masked, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/ICAno12MPy.png')

# %% [markdown]
# # Neurosynth

# %%
zstat='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/zstat_EPI.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(zstat, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/zstatz.png')
plotting.plot_stat_map(zstat, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/zstatx.png')
plotting.plot_stat_map(zstat, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/zstaty.png')

# %%
zstat_bin='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/zstat_EPI_bin.nii.gz'
bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/anatomical_EPI.nii.gz'
plotting.plot_stat_map(zstat_bin, bg_img, display_mode='z', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/zstat_binz.png')
plotting.plot_stat_map(zstat_bin, bg_img, display_mode='x', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/zstat_binx.png')
plotting.plot_stat_map(zstat_bin, bg_img, display_mode='y', cut_coords=10, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/zstat_biny.png')

# %% [markdown]
# # plot each group separately

# %%
control='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_control.gfeat/cope1.feat/thresh_zstat1.nii.gz'
sBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_sBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
eBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_eBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJsBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_MJsBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJeBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_MJeBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'

bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/mid/anatomical_EPI.nii.gz'

plotting.plot_stat_map(control, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(sBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(eBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

# %%
plotting.plot_stat_map(control, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/con_CorStopvCorGo')

plotting.plot_stat_map(sBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/sBinge_CorStopvCorGo')

plotting.plot_stat_map(eBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/eBinge_CorStopvCorGo')

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/MJsBinge_CorStopvCorGo')

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/fig/MJeBinge_CorStopvCorGo')

# %%
control='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_control.gfeat/cope1.feat/thresh_zstat1.nii.gz'
sBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_sBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
eBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_eBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJsBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_MJsBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJeBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/stopsignal/noICA/CorStop-CorGo_MJeBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'

bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/mid/anatomical_EPI.nii.gz'

plotting.plot_stat_map(control, bg_img, display_mode='x', cut_coords=15, colorbar=True)

plotting.plot_stat_map(sBinge, bg_img, display_mode='x', cut_coords=15, colorbar=True)

plotting.plot_stat_map(eBinge, bg_img, display_mode='x', cut_coords=15, colorbar=True)

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='x', cut_coords=15, colorbar=True)

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='x', cut_coords=15, colorbar=True)
