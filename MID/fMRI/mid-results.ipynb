# %%
from nilearn import plotting
from nilearn import image
# %matplotlib inline

# %%
control='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/control.gfeat/cope1.feat/thresh_zstat1.nii.gz'
sBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/sBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
eBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/eBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJsBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/MJsBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJeBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/MJeBinge.gfeat/cope1.feat/thresh_zstat1.nii.gz'

bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/mid/anatomical_EPI.nii.gz'

plotting.plot_stat_map(control, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/control_gain5v0')

plotting.plot_stat_map(sBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/sBinge_gain5v0')

plotting.plot_stat_map(eBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/eBinge_gain5v0')

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/MJsBinge_gain5v0')

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/MJeBinge_gain5v0')

# %%
plotting.plot_stat_map(control, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/control_gain5v0')

plotting.plot_stat_map(sBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/sBinge_gain5v0')

plotting.plot_stat_map(eBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/eBinge_gain5v0')

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/MJsBinge_gain5v0')

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/MJeBinge_gain5v0')

# %%
control='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/control+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
sBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/sBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
eBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/eBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJsBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/MJsBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJeBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/MJeBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'

bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/mid/anatomical_EPI.nii.gz'

plotting.plot_stat_map(control, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/control_gain5v0')

plotting.plot_stat_map(sBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/sBinge_gain5v0')

plotting.plot_stat_map(eBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/eBinge_gain5v0')

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/MJsBinge_gain5v0')

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True,
                      output_file='/Shared/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/figure/MJeBinge_gain5v0')

# %%
control='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/control+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
sBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/sBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
eBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/eBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJsBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/MJsBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'
MJeBinge='/oleary/functional/UICL/BIDS/derivatives/group_analysis/mid/Gain5vs0/MJeBinge+.gfeat/cope1.feat/thresh_zstat1.nii.gz'

bg_img='/oleary/functional/UICL/BIDS/derivatives/group_analysis/neurosynth/mid/anatomical_EPI.nii.gz'

plotting.plot_stat_map(control, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(sBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(eBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(MJsBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)

plotting.plot_stat_map(MJeBinge, bg_img, display_mode='z', cut_coords=15, colorbar=True)
